# %%
# Set Example
myset = {"Joseph", "Kamara", "Ugochi", "Adaobi"}

# loop through set
for a in myset:
    print(a)
    
# checking whether 2 exists in myset
print(2 in myset)

# adding new element
myset.add(99)
print(myset)
# Out:
# Ugochi
# Kamara
# Adaobi
# Joseph
# False
# {99, 'Ugochi', 'Kamara', 'Adaobi', 'Joseph'}
